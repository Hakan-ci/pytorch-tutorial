# %%
import torch

# %%
X = torch.tensor([1.2, -3.2, 2.6])

# %%
X
# Out:
# tensor([ 1.2000, -3.2000,  2.6000])

# %%
X.relu()
# Out:
# tensor([1.2000, 0.0000, 2.6000])

# %%
X
# Out:
# tensor([ 1.2000, -3.2000,  2.6000])

# %%
X.device
# Out:
# device(type='cpu')

# %%
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

# %%
X = X.to(device)

# %%
X.device
# Out:
# device(type='cuda', index=0)

# %%
y = torch.tensor([2.3, -2.4, 6,3])

# %%
y.device
# Out:
# device(type='cpu')

# %%
y = y.to("cuda")

# %%
y.device
# Out:
# device(type='cuda', index=0)

# %%
z = torch.tensor([2, 4, 5,], device="cuda")

# %%
z.device
# Out:
# device(type='cuda', index=0)

# %%
M = torch.rand((1000, 1000))

# %%
# %timeit M @ M
# Out:
# 17.6 ms ± 3.7 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
M = M.to(device)

# %%
# %timeit M @ M
# Out:
# 687 µs ± 8.43 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
