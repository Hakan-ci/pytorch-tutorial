# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.9879, 0.2197, 0.0764],
#         [0.7571, 0.6854, 0.4101],
#         [0.6359, 0.3017, 0.8449],
#         [0.7741, 0.7480, 0.5759],
#         [0.5645, 0.5294, 0.0702]])

# %%
X = torch.tensor([[1, 4, 3],[3, 2, 0]])
X
# Out:
# tensor([[1, 4, 3],
#         [3, 2, 0]])

# %%
X.shape
# Out:
# torch.Size([2, 3])

# %%
X.dtype
# Out:
# torch.int64

# %%
X[:,1:2]
# Out:
# tensor([[4],
#         [2]])

# %%
X + 1
# Out:
# tensor([[2, 5, 4],
#         [4, 3, 1]])

# %%
X * 2
# Out:
# tensor([[2, 8, 6],
#         [6, 4, 0]])

# %%
X.T
# Out:
# tensor([[1, 3],
#         [4, 2],
#         [3, 0]])

# %%
X.max()
# Out:
# tensor(4)

# %%
a = torch.tensor([1,2,3])
b = torch.tensor([4,3,4])

# %%
a @ b
# Out:
# tensor(22)

# %%
a * b
# Out:
# tensor([ 4,  6, 12])

# %%
import numpy as np
c = torch.FloatTensor(np.array((2,3,4)))
c.dtype
# Out:
# torch.float32

# %%
c = torch.tensor(np.array((2.2,3.1,4.3)), dtype= torch.float32)
c.dtype
# Out:
# torch.float32

# %%
X = torch.tensor([1.2, -1.3, 3.23])

# %%
X.dtype
# Out:
# torch.float32

# %%
X.relu()
# Out:
# tensor([1.2000, 0.0000, 3.2300])

# %%
X
# Out:
# tensor([ 1.2000, -1.3000,  3.2300])

# %%
X.relu_() # in-place operation
# Out:
# tensor([1.2000, 0.0000, 3.2300])

# %%
X
# Out:
# tensor([1.2000, 0.0000, 3.2300])

# %%
X.device
# Out:
# device(type='cpu')

# %%
x = torch.tensor(3.0, requires_grad=True)

# %%
f = x ** 2

# %%
f
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
f.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %%
learning_rate = 0.1
with torch.no_grad():
    x -= learning_rate * x.grad

# %%
x
# Out:
# tensor(1.8000, requires_grad=True)
